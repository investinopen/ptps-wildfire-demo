# %% [markdown]
# # Rescue sample datasets
#
# Runs [`Resolver.get_rescue`](../ptps_wildfire_demo/proxy/resolver.py) concurrently against ["No auth, pull directly" datasets](https://docs.google.com/document/d/1rYsP1I1-TAd3Tu-G6EJ-5o7IbQIHf_dKT3DjH8IpQuo/edit?tab=t.0#heading=h.esl5qc9xawjg).

# %% [markdown]
# Adjust import path:

# %%
import sys
from pathlib import Path

repo_root = next(
    path
    for path in (Path.cwd(), *Path.cwd().parents)
    if (path / "ptps_wildfire_demo").is_dir()
)
sys.path.insert(0, str(repo_root))

# %%
import asyncio

import httpx

from ptps_wildfire_demo.proxy.resolver import Resolver

# all datasets under "No auth, pull directly"
urls = [
    "https://data.source.coop/cboettig/fire/usgs-mtbs.parquet",
    "https://data-usfs.hub.arcgis.com/datasets/usfs::probabilistic-wildfire-risk-burn-probability-image-service/explore?location=45.200890%2C-122.025647%2C2",
    "https://wildfirerisk.org/download/",
    "https://source.coop/carbonplan/carbonplan-ocr",
    "https://source.coop/cboettig/fire",
    "https://source.coop/bkr/obs",
    "https://source.coop/giswqs/nwi",
    "https://api.weather.gov/alerts/active?event=Red%20Flag%20Warning",
    "https://www.ospo.noaa.gov/products/land/hms.html",
    "https://www.ncdc.noaa.gov/stormevents/",
    "https://firms.modaps.eosdis.nasa.gov/",
    "https://data-nifc.opendata.arcgis.com/",
    "https://gis.blm.gov/arcgis/rest/services/fire/BLM_Natl_FirePerimeter/MapServer",
    "https://modis.gsfc.nasa.gov/data/dataprod/mod13.php",
    "https://dataspace.copernicus.eu/",
    "https://overpass-api.de/",
    "https://www.landfire.gov/",
    "https://www.landfire.gov/fuel/seasonal_fuels",
]

client = httpx.AsyncClient()
resolver = Resolver(client)

# %%
rescues = await asyncio.gather(*(resolver.get_rescue(url) for url in urls))
# rescues

# %%
import pandas as pd

pd.set_option("display.max_colwidth", 200)
pd.DataFrame(rescues)
# Out:
#                                                                                                                                                original_url  \
# 0                                                                                                  https://data.source.coop/cboettig/fire/usgs-mtbs.parquet
# 1   https://data-usfs.hub.arcgis.com/datasets/usfs::probabilistic-wildfire-risk-burn-probability-image-service/explore?location=45.200890%2C-122.025647%2C2
# 2                                                                                                                        https://wildfirerisk.org/download/
# 3                                                                                                             https://source.coop/carbonplan/carbonplan-ocr
# 4                                                                                                                         https://source.coop/cboettig/fire
# 5                                                                                                                               https://source.coop/bkr/obs
# 6                                                                                                                            https://source.coop/giswqs/nwi
# 7                                                                                          https://api.weather.gov/alerts/active?event=Red%20Flag%20Warning
# 8                                                                                                          https://www.ospo.noaa.gov/products/land/hms.html
# 9                                                                                                                    https://www.ncdc.noaa.gov/stormevents/
# 10                                                                                                                    https://firms.modaps.eosdis.nasa.gov/
# 11                                                                                                                   https://data-nifc.opendata.arcgis.com/
# 12                                                                           https://gis.blm.gov/arcgis/rest/services/fire/BLM_Natl_FirePerimeter/MapServer
# 13                                                                                                      https://modis.gsfc.nasa.gov/data/dataprod/mod13.php
# 14                                                                                                                         https://dataspace.copernicus.eu/
# 15                                                                                                                                 https://overpass-api.de/
# 16                                                                                                                                https://www.landfire.gov/
# 17                                                                                                             https://www.landfire.gov/fuel/seasonal_fuels
#
#                                                                                                           wayback_newest_url  \
# 0                                                                                                                        NaN
# 1                                                                                                                        NaN
# 2                                               http://web.archive.org/web/20260805131156/https://wildfirerisk.org/download/
# 3                                    http://web.archive.org/web/20260412224739/https://source.coop/carbonplan/carbonplan-ocr
# 4                                                http://web.archive.org/web/20260517053656/https://source.coop/cboettig/fire
# 5                                                      http://web.archive.org/web/20260815165154/https://source.coop/bkr/obs
# 6                                                   http://web.archive.org/web/20260803053438/https://source.coop/giswqs/nwi
# 7                                                                                                                        NaN
# 8                                                                                                                        NaN
# 9                                           http://web.archive.org/web/20250810191720/https://www.ncdc.noaa.gov/stormevents/
# 10                                           http://web.archive.org/web/20260821120643/https://firms.modaps.eosdis.nasa.gov/
# 11                                          http://web.archive.org/web/20260708104232/https://data-nifc.opendata.arcgis.com/
# 12  http://web.archive.org/web/20260124062811/https://gis.blm.gov/arcgis/rest/services/fire/BLM_Natl_FirePerimeter/MapServer
# 13                             http://web.archive.org/web/20260814014405/https://modis.gsfc.nasa.gov/data/dataprod/mod13.php
# 14                                                http://web.archive.org/web/20260822060028/https://dataspace.copernicus.eu/
# 15                                                        http://web.archive.org/web/20260731114215/https://overpass-api.de/
# 16                                                           http://web.archive.org/web/20260727230322/https://landfire.gov/
# 17                                    http://web.archive.org/web/20251220003311/https://www.landfire.gov/fuel/seasonal_fuels
#
#    drp_metadata_url drp_download_location
# 0              None                  None
# 1              None                  None
# 2              None                  None
# 3              None                  None
# 4              None                  None
# 5              None                  None
# 6              None                  None
# 7              None                  None
# 8              None                  None
# 9              None                  None
# 10             None                  None
# 11             None                  None
# 12             None                  None
# 13             None                  None
# 14             None                  None
# 15             None                  None
# 16             None                  None
# 17             None                  None
